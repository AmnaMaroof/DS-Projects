# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Task # 1
# Create a dataset for representing 5 attributes that reflect the cause of a failure in examination (using an
# approach other than List to List and Dic to List.). The three most common attributes are (‘test_score’,
# ‘writing skill’, and ‘reading skill’) decide two attributes by yourself. Fill in at least 10 records. Come up
# with 2 more different ideas to Create a Data Frame

# %%
np.random.seed(42)
random_size= 10

student_id=np.random.randint(1,20, random_size)
test_score=np.random.randint(25.5,100, random_size)
writing_skill=np.random.randint(25.5,100, random_size)
reading_skill=np.random.randint(25.5,100, random_size)
study_hours=np.random.randint(2,10, random_size)
attendance_percentage=np.random.randint(75,100, random_size)

Data_set_1=pd.DataFrame({
    "student_id":student_id,
    "test_score":test_score,
    "writing_skill":writing_skill,
    "reading_skill":reading_skill,
    "study_hours":study_hours,
    "attendance_percentage":attendance_percentage
})
Data_set_1
# Out:
#    student_id  test_score  writing_skill  reading_skill  study_hours  \
# 0           7          48             45             86            2
# 1          15          27             57             71            8
# 2          11          46             82             86            3
# 3           8          77             46             75            5
# 4           7          26             73             79            2
# 5          19          54             83             88            5
# 6          11          62             66             27            7
# 7          11          26             84             75            3
# 8           4          88             39             31            3
# 9           8          84             86             45            2
#
#    attendance_percentage
# 0                     95
# 1                     76
# 2                     94
# 3                     89
# 4                     81
# 5                     86
# ...

# %% [markdown]
# ### np.random.randint
# (low, high, size): Generates random integers from low (inclusive) to high (exclusive) with the specified size (number of integers).
# ### np.column_stack(arrays):
#  This combines the individual arrays (columns) into a single 2D array (matrix). Each column corresponds to one of the attributes and each row corresponds to one data point.
# Stacks the input arrays as columns into a single 2D array. This results in a 2D array where each row represents a data point with all attributes.

# %%
np.random.seed(42)
random_size = 10

student_id=np.random.randint(1, 20, random_size)
test_score=np.random.randint(25, 100, random_size)
writing_skill=np.random.randint(25, 100, random_size)
reading_skill=np.random.randint(25, 100, random_size)
study_hours=np.random.randint(2, 10, random_size)
attendance_percentage=np.random.randint(75, 100, random_size)

# Combine the arrays into a dataset
Data_set_2= np.column_stack((student_id, test_score, writing_skill, reading_skill, study_hours, attendance_percentage))

# Convert to DataFrame
Data_set_2 = pd.DataFrame(Data_set_2, columns=['student_id', 'test_score', 'writing_skill', 'reading_skill', 'study_hours', 'attendance_percentage'])

print(Data_set_2)
# Out:
#    student_id  test_score  writing_skill  reading_skill  study_hours  \
# 0           7          48             45             86            2
# 1          15          27             57             71            8
# 2          11          46             82             86            3
# 3           8          77             46             75            5
# 4           7          26             73             79            2
# 5          19          54             83             88            5
# 6          11          62             66             27            7
# 7          11          26             84             75            3
# 8           4          88             39             31            3
# 9           8          84             86             45            2
#
#    attendance_percentage
# 0                     95
# 1                     76
# 2                     94
# 3                     89
# 4                     81
# 5                     86
# ...

# %% [markdown]
# # Task # 2

# %% [markdown]
# B. Import your dataset in Colab or Jupyter notebook

# %%
cancer=pd.read_csv(r"C:\Users\Maaz\Downloads\cancer patient data sets.csv")
cancer.head(50)
# Out:
#     index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0       0         P1   33       1              2            4             5
# 1       1        P10   17       1              3            1             5
# 2       2       P100   35       1              4            5             6
# 3       3      P1000   37       1              7            7             7
# 4       4       P101   46       1              6            8             7
# 5       5       P102   35       1              4            5             6
# 6       6       P103   52       2              2            4             5
# 7       7       P104   28       2              3            1             4
# 8       8       P105   35       2              4            5             6
# 9       9       P106   46       1              2            3             4
# 10     10       P107   44       1              6            7             7
# ...

# %% [markdown]
# Find out the total number of columns in the entire dataset, Check out the first 50 records of the dataset
# and + the bottom 30 records. Find its Information related to memory size, its dimension and explore the
# size and dimension of your dataset

# %%
cancer.tail(30)
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 970    970       P972   48       2              6            8             7
# 971    971       P973   36       2              2            1             5
# 972    972       P974   31       2              3            2             4
# 973    973       P975   38       2              1            2             3
# 974    974       P976   35       1              6            8             7
# 975    975       P977   44       1              6            7             7
# 976    976       P978   33       1              2            4             5
# 977    977       P979   45       1              3            1             4
# 978    978        P98   26       2              8            8             7
# 979    979       P980   53       1              3            1             4
# 980    980       P981   35       2              4            5             6
# ...

# %%
cancer.isna().sum().sum()
# Out:
# 0

# %%
cancer.info
# Out:
# <bound method DataFrame.info of      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
cancer.shape[1]
# Out:
# 26

# %%
cancer.shape[0]
# Out:
# 1000

# %%
cancer.dtypes
# Out:
# index                        int64
# Patient Id                  object
# Age                          int64
# Gender                       int64
# Air Pollution                int64
# Alcohol use                  int64
# Dust Allergy                 int64
# OccuPational Hazards         int64
# Genetic Risk                 int64
# chronic Lung Disease         int64
# Balanced Diet                int64
# Obesity                      int64
# Smoking                      int64
# Passive Smoker               int64
# Chest Pain                   int64
# Coughing of Blood            int64
# Fatigue                      int64
# Weight Loss                  int64
# Shortness of Breath          int64
# Wheezing                     int64
# Swallowing Difficulty        int64
# Clubbing of Finger Nails     int64
# Frequent Cold                int64
# Dry Cough                    int64
# Snoring                      int64
# Level                       object
# dtype: object

# %% [markdown]
# Find the number of columns and total number of samples. Find out the number of records for each
# unique category of
#  target variable using numerical and graphical visualization.

# %%
len(cancer)
# Out:
# 1000

# %%
target_variable= 'Level'
unique_values=cancer[target_variable].unique()
unique_values
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
counts=cancer['Level'].value_counts()
counts
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %% [markdown]
# ### autopct='%1.1f%%': This adds the percentage value to each slice of the pie chart.

# %%
cancer['Level'].value_counts().plot.pie(autopct='%1.1f%%', colors=['teal', 'lavender', 'grey'])
plt.title('Distribution of Target Variable (Level)')
plt.ylabel('')  # Remove y-label for clarity
plt.show()

# %% [markdown]
# Extract the sample from the 550th sample to the 900th sample and take these features Gender to
# Coughing of Blood using the Loc Method and storing them in a new variable. Save this dataset in a new
# place and apply statistical analysis to these extracted records In statistical analysis you have to find out
# the mean, median, mode, standard deviation, minimum, and maximum

# %%
cancer_data_subset=cancer.loc[550:900, "Gender":"Dry Cough"]
cancer_data_subset.head(5)
# Out:
#      Gender  Air Pollution  Alcohol use  Dust Allergy  OccuPational Hazards  \
# 550       1              6            7             7                     7
# 551       1              6            7             7                     7
# 552       2              6            8             7                     7
# 553       2              4            5             6                     5
# 554       2              6            8             7                     7
#
#      Genetic Risk  chronic Lung Disease  Balanced Diet  Obesity  Smoking  ...  \
# 550             7                     7              6        7        7  ...
# 551             7                     6              7        7        7  ...
# 552             7                     6              7        7        7  ...
# 553             5                     4              6        7        2  ...
# 554             7                     6              7        7        8  ...
#
# ...

# %%
cancer.describe()
# Out:
#              index          Age       Gender  Air Pollution  Alcohol use  \
# count  1000.000000  1000.000000  1000.000000      1000.0000  1000.000000
# mean    499.500000    37.174000     1.402000         3.8400     4.563000
# std     288.819436    12.005493     0.490547         2.0304     2.620477
# min       0.000000    14.000000     1.000000         1.0000     1.000000
# 25%     249.750000    27.750000     1.000000         2.0000     2.000000
# 50%     499.500000    36.000000     1.000000         3.0000     5.000000
# 75%     749.250000    45.000000     2.000000         6.0000     7.000000
# max     999.000000    73.000000     2.000000         8.0000     8.000000
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count   1000.000000           1000.000000   1000.000000           1000.000000
# mean       5.165000              4.840000      4.580000              4.380000
# ...

# %%
mean_values = cancer.groupby(["Level"]).agg({
    "Age":"mean",	
    "Gender":"mean",
    "Air Pollution":"mean",	
    "Alcohol use":"mean",	
    "Dust Allergy":"mean",	
    "OccuPational Hazards":"mean",	
    "Genetic Risk":"mean",	
    "chronic Lung Disease":"mean",	
    "Fatigue":"mean",
    "Weight Loss":"mean",	
    "Shortness of Breath":"mean",	
    "Wheezing":"mean",	
    "Swallowing Difficulty":"mean",	
    "Clubbing of Finger Nails":"mean",	
    "Frequent Cold":"mean",
    "Dry Cough":"mean",
    "Snoring":"mean",
    })
mean_values
# Out:
#               Age    Gender  Air Pollution  Alcohol use  Dust Allergy  \
# Level
# High    37.320548  1.309589       5.693151     6.830137      6.616438
# Low     35.412541  1.508251       2.600660     2.231023      3.112211
# Medium  38.620482  1.406627       2.933735     4.198795      5.442771
#
#         OccuPational Hazards  Genetic Risk  chronic Lung Disease   Fatigue  \
# Level
# High                6.479452      6.375342              5.827397  5.589041
# Low                 3.000000      2.732673              3.092409  2.171617
# Medium              4.716867      4.292169              3.963855  3.487952
#
#         Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# Level
# High       4.468493             5.328767  3.884932               4.189041
# Low        2.501650             2.498350  2.574257               2.759076
# Medium     4.415663             4.632530  4.756024               4.159639
#
# ...

# %%
median_values = cancer.groupby(["Level"]).agg({
    "Age":"median",	
    "Gender":"median",
    "Air Pollution":"median",	
    "Alcohol use":"median",	
    "Dust Allergy":"median",	
    "OccuPational Hazards":"median",	
    "Genetic Risk":"median",	
    "chronic Lung Disease":"median",	
    "Fatigue":"median",
    "Weight Loss":"median",	
    "Shortness of Breath":"median",	
    "Wheezing":"median",	
    "Swallowing Difficulty":"median",	
    "Clubbing of Finger Nails":"median",	
    "Frequent Cold":"median",
    "Dry Cough":"median",
    "Snoring":"median",
    })
median_values
# Out:
#          Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# Level
# High    36.0     1.0            6.0          7.0           7.0
# Low     33.0     2.0            3.0          2.0           3.0
# Medium  38.0     1.0            2.0          4.0           5.0
#
#         OccuPational Hazards  Genetic Risk  chronic Lung Disease  Fatigue  \
# Level
# High                     7.0           7.0                   6.0      5.0
# Low                      3.0           2.0                   3.0      2.0
# Medium                   5.0           3.0                   4.0      4.0
#
#         Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# Level
# High            5.0                  5.0       2.0                    4.0
# Low             2.0                  2.0       2.0                    2.0
# Medium          5.0                  6.0       5.0                    4.0
#
#         Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring
# Level
# ...

# %%
max_values = cancer.groupby(["Level"]).agg({
    "Age":"max",	
    "Gender":"max",
    "Air Pollution":"max",	
    "Alcohol use":"max",	
    "Dust Allergy":"max",	
    "OccuPational Hazards":"max",	
    "Genetic Risk":"max",	
    "chronic Lung Disease":"max",	
    "Fatigue":"max",
    "Weight Loss":"max",	
    "Shortness of Breath":"max",	
    "Wheezing":"max",	
    "Swallowing Difficulty":"max",	
    "Clubbing of Finger Nails":"max",	
    "Frequent Cold":"max",
    "Dry Cough":"max",
    "Snoring":"max",
    })
max_values
# Out:
#         Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# Level
# High     64       2              8            8             7
# Low      62       2              6            7             8
# Medium   73       2              6            8             7
#
#         OccuPational Hazards  Genetic Risk  chronic Lung Disease  Fatigue  \
# Level
# High                       7             7                     7        9
# Low                        7             7                     7        4
# Medium                     8             7                     6        6
#
#         Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# Level
# High              7                    9         7                      8
# Low               8                    7         4                      8
# Medium            7                    7         8                      8
#
#         Clubbing of Finger Nails  Frequent Cold  Dry Cough  Snoring
# Level
# ...

# %%
std_values = cancer.groupby(["Level"]).agg({
    "Age":"std",	
    "Gender":"std",
    "Air Pollution":"std",	
    "Alcohol use":"std",	
    "Dust Allergy":"std",	
    "OccuPational Hazards":"std",	
    "Genetic Risk":"std",	
    "chronic Lung Disease":"std",	
    "Fatigue":"std",
    "Weight Loss":"std",	
    "Shortness of Breath":"std",	
    "Wheezing":"std",	
    "Swallowing Difficulty":"std",	
    "Clubbing of Finger Nails":"std",	
    "Frequent Cold":"std",
    "Dry Cough":"std",
    "Snoring":"std",
    })
std_values
# Out:
#               Age    Gender  Air Pollution  Alcohol use  Dust Allergy  \
# Level
# High    10.724253  0.462959       1.274898     1.157238      0.917326
# Low     12.126736  0.500759       1.110873     1.260490      1.659994
# Medium  13.015234  0.491945       1.874090     2.650246      1.464497
#
#         OccuPational Hazards  Genetic Risk  chronic Lung Disease   Fatigue  \
# Level
# High                0.982115      0.821380              1.002916  2.371046
# Low                 1.524632      1.432067              1.696717  0.897155
# Medium              2.036959      2.068801              1.605849  1.498188
#
#         Weight Loss  Shortness of Breath  Wheezing  Swallowing Difficulty  \
# Level
# High       2.107605             2.255974  2.602391               2.345182
# Low        1.604783             1.450907  1.026276               1.645194
# Medium     2.247952             2.000882  1.369982               2.399987
#
# ...

# %%
cancer.mode()
# Out:
#      index Patient Id   Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1  35.0     1.0            6.0          2.0           7.0
# 1        1        P10   NaN     NaN            NaN          NaN           NaN
# 2        2       P100   NaN     NaN            NaN          NaN           NaN
# 3        3      P1000   NaN     NaN            NaN          NaN           NaN
# 4        4       P101   NaN     NaN            NaN          NaN           NaN
# ..     ...        ...   ...     ...            ...          ...           ...
# 995    995       P995   NaN     NaN            NaN          NaN           NaN
# 996    996       P996   NaN     NaN            NaN          NaN           NaN
# 997    997       P997   NaN     NaN            NaN          NaN           NaN
# 998    998       P998   NaN     NaN            NaN          NaN           NaN
# 999    999       P999   NaN     NaN            NaN          NaN           NaN
#
# ...

# %% [markdown]
# Extract sample of last 20 records, consider 5 features from Shortness of Breath to Frequent cold
# column using iLoc Method Save this dataset in a new place and apply statistical analysis on these
# extracted records

# %%
cancer_data_subset_1=cancer.iloc[:,-8:]
cancer_data_subset_1.tail(20)
# Out:
#      Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 980                    9         2                      1
# 981                    4         1                      4
# 982                    6         7                      6
# 983                    6         5                      5
# 984                    2         4                      6
# 985                    2         7                      8
# 986                    5         7                      2
# 987                    9         2                      1
# 988                    4         1                      4
# 989                    3         1                      4
# 990                    9         2                      1
# 991                    4         1                      4
# 992                    6         7                      6
# 993                    3         1                      4
# 994                    7         6                      7
# ...

# %%
cancer_data_subset_1.describe()
# Out:
#        Shortness of Breath     Wheezing  Swallowing Difficulty  \
# count          1000.000000  1000.000000            1000.000000
# mean              4.240000     3.777000               3.746000
# std               2.285087     2.041921               2.270383
# min               1.000000     1.000000               1.000000
# 25%               2.000000     2.000000               2.000000
# 50%               4.000000     4.000000               4.000000
# 75%               6.000000     5.000000               5.000000
# max               9.000000     8.000000               8.000000
#
#        Clubbing of Finger Nails  Frequent Cold    Dry Cough      Snoring
# count               1000.000000    1000.000000  1000.000000  1000.000000
# mean                   3.923000       3.536000     3.853000     2.926000
# std                    2.388048       1.832502     2.039007     1.474686
# min                    1.000000       1.000000     1.000000     1.000000
# ...

# %% [markdown]
# Extract sample of these records 110, 220, 360, 440, 656, 778, 202, 889. Take all features in
# consideration. Check out the average alcohol use in these records.

# %%
x= [110, 220, 360, 440, 656, 778, 202, 889]
cancer_df = cancer.loc[x]
cancer_df
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 110    110       P198   18       2              6            8             7
# 220    220       P297   25       2              4            5             6
# 360    360       P422   19       1              3            2             4
# 440    440       P495   44       1              6            7             7
# 656    656        P69   52       1              6            8             7
# 778    778         P8   27       2              3            1             4
# 202    202       P280   53       1              6            8             7
# 889    889         P9   73       1              5            6             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 110                     7             7                     6  ...        3
# 220                     5             5                     4  ...        8
# ...

# %%
average= sum(cancer["Alcohol use"])/len(cancer["Alcohol use"])
average
# Out:
# 4.563

# %% [markdown]
# Perform Graphical Visualization

# %%
visualization= cancer[
    ["Age","Gender", "Air Pollution","Alcohol use","Dust Allergy"]
]

# %%
fig, axs = plt.subplots(nrows=5, figsize=(25,20))

sns.histplot(x=cancer["Age"],ax=axs[0])
sns.histplot(x=cancer["Gender"],ax=axs[1])
sns.histplot(x=cancer["Air Pollution"],ax=axs[2])
sns.histplot(x=cancer["Alcohol use"],ax=axs[3])
sns.histplot(x=cancer["Dust Allergy"],ax=axs[4])


plt.show()

# %%
visualization_1= cancer[
    ["OccuPational Hazards","Genetic Risk","chronic Lung Disease",  "Fatigue", "Weight Loss","Shortness of Breath"]
]

# %%
fig, axs = plt.subplots(nrows=6, figsize=(25,20))

sns.kdeplot(x=cancer["OccuPational Hazards"],ax=axs[0])
sns.kdeplot(x=cancer["Genetic Risk"],ax=axs[1])
sns.kdeplot(x=cancer["chronic Lung Disease"],ax=axs[2])

sns.kdeplot(x=cancer["Fatigue"],ax=axs[3])
sns.kdeplot(x=cancer["Weight Loss"],ax=axs[4])
sns.kdeplot(x=cancer["Shortness of Breath"],ax=axs[5])

plt.show()

# %%
visualization_2= cancer[
    ["Shortness of Breath","Wheezing","Swallowing Difficulty","Clubbing of Finger Nails",
    "Dry Cough","Snoring"]
]

# %%
fig, axs = plt.subplots(nrows=5, figsize=(25,20))

sns.histplot(x=cancer["Wheezing"],ax=axs[0])
sns.histplot(x=cancer["Swallowing Difficulty"],ax=axs[1])
sns.histplot(x=cancer["Clubbing of Finger Nails"],ax=axs[2])
sns.histplot(x=cancer["Dry Cough"],ax=axs[3])
sns.histplot(x=cancer["Snoring"],ax=axs[4])


plt.show()

# %%
#Distribution plot of 'Alcohol use'

sns.histplot(cancer['Age'], kde=True)
plt.title('distribution of Age')
plt.xlabel('Age')
plt.ylabel('Level')
plt.show()

# Distribution plot of 'Frequent Cold'

sns.histplot(cancer['Frequent Cold'], kde=True)
plt.title('distribution of Frequent Cold')
plt.xlabel('Frequent Cold')
plt.ylabel('Level')
plt.show()

# %% [markdown]
# Find out outliers in Obesity feature by using Graphical Visualization

# %%
# Plot histogram
sns.boxplot(x=cancer["Obesity"])
plt.show()

# %%
# dtype conversation
cancer['Level'] = cancer['Level'].replace(['Low', 'Medium','High'], [0, 1, 2])

# %%
cancer.drop("Patient Id", axis=1, inplace=True)

# %%
cancer.dtypes
# Out:
# index                       int64
# Age                         int64
# Gender                      int64
# Air Pollution               int64
# Alcohol use                 int64
# Dust Allergy                int64
# OccuPational Hazards        int64
# Genetic Risk                int64
# chronic Lung Disease        int64
# Balanced Diet               int64
# Obesity                     int64
# Smoking                     int64
# Passive Smoker              int64
# Chest Pain                  int64
# Coughing of Blood           int64
# Fatigue                     int64
# Weight Loss                 int64
# Shortness of Breath         int64
# Wheezing                    int64
# Swallowing Difficulty       int64
# Clubbing of Finger Nails    int64
# Frequent Cold               int64
# Dry Cough                   int64
# Snoring                     int64
# Level                       int64
# dtype: object

# %%
# Plot correlation
plt.figure(figsize=(45,45))
sns.heatmap(
    data=cancer.corr(), 
    xticklabels=cancer.columns.values,
    yticklabels=cancer.columns.values, 
    annot=True, 
    annot_kws={'size': 12}
)
# Axis ticks size
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.show()
